# %% [markdown]
# # Ising model

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import randint, choice, random
from IPython.display import clear_output, display
# %matplotlib inline

# %%
def calculate_energy(grid, J):
    E = 0
    N = grid.shape[0]
    for x in range(N):
        for y in range(N):
            E += -J * grid[x, y] * (grid[x, (y+1)%N] +
                                    grid[x, (y-1)%N] +
                                    grid[(x+1)%N, y] +
                                    grid[(x-1)%N, y])
    return E / 4.0 / (N*N)
    
def simulate(T, eq_T, n_T, N=16, J=1.0):
    grid = choice([-1.0, 1.0], (N, N))
    magnetization = np.zeros(n_T-eq_T)
    energy = np.zeros(n_T-eq_T)

    for t in range(n_T):
        x = randint(0, N)
        y = randint(0, N)
        E = -J * grid[x, y] * (grid[x, (y+1)%N] +
                               grid[x, (y-1)%N] +
                               grid[(x+1)%N, y] +
                               grid[(x-1)%N, y])

        if E > 0 or random() < np.exp(2.0 * E / T):
            grid[x, y] = grid[x, y] * -1
        
        if t > eq_T:
            magnetization[t-eq_T] = np.average(grid)
            energy[t-eq_T] = calculate_energy(grid, J)
            
    M = np.average(magnetization)
    M2 = np.average(magnetization**2.0)
    E = np.average(energy)
    E2 = np.average(energy**2.0)
    C = (E2 - E**2.0) / T**2.0
    S = (M2 - M**2.0) / T
            
    return grid, M, E, C, S

# %%
temps = np.arange(1.6, 5.0, 0.1)
magnetization, energy, specific_heat, susceptibility = np.zeros(len(temps)), np.zeros(len(temps)), np.zeros(len(temps)), np.zeros(len(temps))
n_T = 10**5
equilibrium_time = int(n_T * 2 / 3)

for i, T in enumerate(temps):
    simulation = simulate(T, equilibrium_time, n_T)
    magnetization[i] = simulation[1]
    energy[i] = simulation[2]
    specific_heat[i] = simulation[3]
    susceptibility[i] = simulation[4]
    clear_output(wait=True)
    print("{} of {}".format(i, len(temps)-1))
# Out:
# 33 of 33

# %%
plt.title('Magnetization as a function of temperature')
plt.scatter(temps, np.abs(magnetization))
plt.grid()

plt.figure()
plt.title('Energy as a function of temperature')
plt.scatter(temps, energy)
plt.grid()

plt.figure()
plt.title('Specific heat as a function of temperature')
plt.scatter(temps, specific_heat)
plt.grid()

plt.figure()
plt.title('Susceptibility as a function of temperature')
plt.scatter(temps, susceptibility)
plt.grid()

plt.show()

# %%
grid = simulate(1.5, 10**6, 10**6, N=128)[0]
plt.figure(figsize=(18, 10))
plt.imshow(grid, cmap='Greys_r')
plt.colorbar()
# Out:
# /home/daniel/.local/lib/python3.5/site-packages/numpy/lib/function_base.py:392: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/daniel/.local/lib/python3.5/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
